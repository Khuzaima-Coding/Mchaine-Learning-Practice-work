# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("insurance.csv")

# %%
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
data.shape
# Out:
# (1338, 7)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
data.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(1)

# %%
data.drop_duplicates(inplace=True)

# %%
data.age.min()
# Out:
# 18

# %%
data.age.max()
# Out:
# 64

# %%
data.boxplot("age")
plt.show()

# %%
data.sex=data.sex.apply(lambda x: 1 if x=="male" else 0)

# %%
data.sex.value_counts()
# Out:
# sex
# 1    675
# 0    662
# Name: count, dtype: int64

# %%
data.boxplot("bmi")
plt.show()

# %% [raw]
# Lets we can do the capping(winsoriation) due to outliers:

# %%
data.bmi.describe()
# Out:
# count    1337.000000
# mean       30.663452
# std         6.100468
# min        15.960000
# 25%        26.290000
# 50%        30.400000
# 75%        34.700000
# max        53.130000
# Name: bmi, dtype: float64

# %%
Q1=data.bmi.quantile(0.25)
Q3=data.bmi.quantile(0.75)

IQR=Q3 -Q1

lower=Q1 - 1.5 * IQR
upper=Q3 + 1.5 * IQR

# %%
lower
# Out:
# np.float64(13.674999999999994)

# %%
upper
# Out:
# np.float64(47.31500000000001)

# %%
data.bmi= data.bmi.clip(lower=lower,upper=upper)

# %%
data.smoker=data.smoker.apply(lambda x: 1 if x=="male" else 0)

# %%
data.region.unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
# we can do this,For datas like categorical ,but it is lenthy
dummy=pd.get_dummies(data.region,dtype=int)
pd.concat([data,dummy],axis=1).drop("region",axis=1)
# Out:
#       age  sex     bmi  children  smoker      charges  northeast  northwest  \
# 0      19    0  27.900         0       0  16884.92400          0          0
# 1      18    1  33.770         1       0   1725.55230          0          0
# 2      28    1  33.000         3       0   4449.46200          0          0
# 3      33    1  22.705         0       0  21984.47061          0          1
# 4      32    1  28.880         0       0   3866.85520          0          1
# ...   ...  ...     ...       ...     ...          ...        ...        ...
# 1333   50    1  30.970         3       0  10600.54830          0          1
# 1334   18    0  31.920         0       0   2205.98080          1          0
# 1335   18    0  36.850         0       0   1629.83350          0          0
# 1336   21    0  25.800         0       0   2007.94500          0          0
# 1337   61    0  29.070         0       0  29141.36030          0          1
#
#       southeast  southwest
# 0             0          1
# ...

# %%
# We can do this work through scikit learn
from sklearn.preprocessing import OneHotEncoder    #,LabelEncoder  # Labels are known as y(predictions), in machine learning.So Label encoding is of pred.

# %%
ohe=OneHotEncoder()
encoded_region=ohe.fit_transform(data[["region"]])

# %%
encoded_region=encoded_region.toarray()

# %%
df=pd.read_csv("insurance.csv")

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
pd.get_dummies(df,dtype=int)
# Out:
#       age     bmi  children      charges  sex_female  sex_male  smoker_no  \
# 0      19  27.900         0  16884.92400           1         0          0
# 1      18  33.770         1   1725.55230           0         1          1
# 2      28  33.000         3   4449.46200           0         1          1
# 3      33  22.705         0  21984.47061           0         1          1
# 4      32  28.880         0   3866.85520           0         1          1
# ...   ...     ...       ...          ...         ...       ...        ...
# 1333   50  30.970         3  10600.54830           0         1          1
# 1334   18  31.920         0   2205.98080           1         0          1
# 1335   18  36.850         0   1629.83350           1         0          1
# 1336   21  25.800         0   2007.94500           1         0          1
# 1337   61  29.070         0  29141.36030           1         0          0
#
#       smoker_yes  region_northeast  region_northwest  region_southeast  \
# ...

# %% [raw]
# Through get dummies ,we can get the one hot code,But if we can call any category from one hot code, So it can read only the one code ,that is 1, But when we use the sklearn OneHotEncoder,So from this can get the complete code of OneHot ,and can be fitted accordingly to the categories,which we can give them for training ,and after when we can transform the test data like this so it can make dummies like the tarining column,and also have the complete code of that category like 1000,1001 etc.So sklearn OneHotEncodig is better.
