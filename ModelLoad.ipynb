# %%
import joblib

mlr = joblib.load('mlr.joblib')

# %%
import joblib
import numpy as np
slr = joblib.load('slr.joblib')

# %%
slr.predict([[74]])
# Out:
# C:\Users\Teacher\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([220.13812754])

# %%
mlr.predict([[0,60]])
# Out:
# C:\Users\Teacher\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([113.7594299])
